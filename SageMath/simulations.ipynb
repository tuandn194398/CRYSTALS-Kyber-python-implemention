# %%
from Kyber import *
import sys
sys.path.insert(1, './polar-codes/polarcodes')
from polarcodes import *
import numpy as np
import time
import datetime

correct, wrong = 0, 0
tests = 100000
start_time = time.time() 
code_rate = 0.5625 # K = 144
SNR  = 53.5 # derived from experimental data 
probability_of_bit_flip_in_channel = 10**-9 # typical
    
for test in range(0, tests):
    message = np.array(string_to_bits("Test!"))
    
    ## Polar Codes setup
    K = len(message)
    N = 256
    while N*code_rate < K:
        N = N*2
    PC = PolarCode(N, K)
    PC.construction_type = 'bb'

    Construct(PC, SNR);
    PC.set_message(message)

    ## Key generation
    pk,sk = generate_keys()

    ## encode message
    Encode(PC);
    encoded = PC.get_codeword()

    ## encrypt message 
    u, v = encrypt(encoded, pk)
    ## Add noise
    noisy_v = add_noise_v(v, probability_of_bit_flip_in_channel)
    noisy_u = add_noise_u(u, probability_of_bit_flip_in_channel)

    decrypted = decrypt(noisy_u, noisy_v, sk, True)
    
    PC.set_codeword(np.array(decrypted), SNR, K/N)
    Decode(PC);
    decoded = list(PC.message_received)

    if all(decoded == message) :
        correct += 1
    else:
        wrong += 1
#         print(print(noisy_u[0]-u[0]))
    if test % (tests//100) == 0:
        print(f"{test} complete at {datetime.datetime.now().hour}:{datetime.datetime.now().minute}:{datetime.datetime.now().second}, with {correct} correct and {wrong} wrong")
total_time = time.time() - start_time
print(f"{correct} correct, {wrong} wrong, in {tests} tests, which took {total_time}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-01f2dcd2c94c> in <module>
#       2 import sys
#       3 sys.path.insert(1, './polar-codes/polarcodes')
# ----> 4 from polarcodes import *
#       5 import numpy as np
#       6 import time
#
# ModuleNotFoundError: No module named 'polarcodes'

# %%
from Kyber import *
from Repetition_code import *
import numpy as np
import time
import datetime

correct, wrong = 0, 0
tests = 1000
start_time = time.time() 
probability_of_bit_flip_in_channel = 10**-9 # typical

for test in range(1, tests):
    message = string_to_bits("Test!")
    
    pk,sk = generate_keys()

    ## encode message
    encoded_small = repetition_encode(message)
    
    closest_power_of_2 = 256
    while len(encoded_small) > closest_power_of_2:
        closest_power_of_2 *= 2 
    encoded = zero_padding(encoded_small, closest_power_of_2)
    ## encrypt message 
    u, v = encrypt(encoded, pk)
    ## Add noise
    noisy_v = add_noise_v(v, probability_of_bit_flip_in_channel)
    noisy_u = add_noise_u(u, probability_of_bit_flip_in_channel)
#     print(noisy_v, noisy_u)

    decrypted = list(decrypt(noisy_u, noisy_v, sk, True))
    
    decoded = bits_to_string(repetition_decode(decrypted))
#     for i in range(33):
#         print(decoded[i], message[i])
    
    if decoded == bits_to_string(message) :
        correct += 1
    else:
        wrong += 1
    if test % (tests//100) == 0:
        print(f"{test} complete at {datetime.datetime.now().hour}:{datetime.datetime.now().minute}:{datetime.datetime.now().second}, with {correct} correct and {wrong} wrong")
total_time = time.time() - start_time
print(f"{correct} correct, {wrong} wrong, in {tests} tests, which took {total_time}")
# Out:
# 10 complete at 16:26:15, with 10 correct and 0 wrong
# 20 complete at 16:26:17, with 20 correct and 0 wrong
# 30 complete at 16:26:19, with 30 correct and 0 wrong
# 40 complete at 16:26:20, with 40 correct and 0 wrong
# 50 complete at 16:26:22, with 50 correct and 0 wrong
# 60 complete at 16:26:24, with 60 correct and 0 wrong
# 70 complete at 16:26:25, with 70 correct and 0 wrong
# 80 complete at 16:26:27, with 80 correct and 0 wrong
# 90 complete at 16:26:29, with 90 correct and 0 wrong
# 100 complete at 16:26:31, with 100 correct and 0 wrong
# 110 complete at 16:26:32, with 110 correct and 0 wrong
# 120 complete at 16:26:34, with 120 correct and 0 wrong
# 130 complete at 16:26:36, with 130 correct and 0 wrong
# 140 complete at 16:26:37, with 140 correct and 0 wrong
# 150 complete at 16:26:39, with 150 correct and 0 wrong
# 160 complete at 16:26:41, with 160 correct and 0 wrong
# 170 complete at 16:26:42, with 170 correct and 0 wrong
# 180 complete at 16:26:44, with 180 correct and 0 wrong
# 190 complete at 16:26:46, with 190 correct and 0 wrong
# 200 complete at 16:26:47, with 200 correct and 0 wrong
# 210 complete at 16:26:49, with 210 correct and 0 wrong
# 220 complete at 16:26:51, with 220 correct and 0 wrong
# 230 complete at 16:26:52, with 230 correct and 0 wrong
# 240 complete at 16:26:54, with 240 correct and 0 wrong
# 250 complete at 16:26:56, with 250 correct and 0 wrong
# 260 complete at 16:26:57, with 260 correct and 0 wrong
# 270 complete at 16:26:59, with 270 correct and 0 wrong
# 280 complete at 16:27:0, with 280 correct and 0 wrong
# 290 complete at 16:27:2, with 290 correct and 0 wrong
# 300 complete at 16:27:4, with 300 correct and 0 wrong
# 310 complete at 16:27:5, with 310 correct and 0 wrong
# 320 complete at 16:27:7, with 320 correct and 0 wrong
# 330 complete at 16:27:9, with 330 correct and 0 wrong
# 340 complete at 16:27:11, with 340 correct and 0 wrong
# 350 complete at 16:27:12, with 350 correct and 0 wrong
# 360 complete at 16:27:14, with 360 correct and 0 wrong
# 370 complete at 16:27:16, with 370 correct and 0 wrong
# 380 complete at 16:27:17, with 380 correct and 0 wrong
# 390 complete at 16:27:19, with 390 correct and 0 wrong
# 400 complete at 16:27:21, with 400 correct and 0 wrong
# 410 complete at 16:27:22, with 410 correct and 0 wrong
# 420 complete at 16:27:24, with 420 correct and 0 wrong
# 430 complete at 16:27:26, with 430 correct and 0 wrong
# 440 complete at 16:27:28, with 440 correct and 0 wrong
# 450 complete at 16:27:29, with 450 correct and 0 wrong
# 460 complete at 16:27:31, with 460 correct and 0 wrong
# 470 complete at 16:27:33, with 470 correct and 0 wrong
# 480 complete at 16:27:34, with 480 correct and 0 wrong
# 490 complete at 16:27:36, with 490 correct and 0 wrong
# 500 complete at 16:27:38, with 500 correct and 0 wrong
# 510 complete at 16:27:39, with 510 correct and 0 wrong
# 520 complete at 16:27:41, with 520 correct and 0 wrong
# 530 complete at 16:27:43, with 530 correct and 0 wrong
# 540 complete at 16:27:45, with 540 correct and 0 wrong
# 550 complete at 16:27:46, with 550 correct and 0 wrong
# 560 complete at 16:27:48, with 560 correct and 0 wrong
# 570 complete at 16:27:50, with 570 correct and 0 wrong
# 580 complete at 16:27:51, with 580 correct and 0 wrong
# 590 complete at 16:27:53, with 590 correct and 0 wrong
# 600 complete at 16:27:55, with 600 correct and 0 wrong
# 610 complete at 16:27:56, with 610 correct and 0 wrong
# 620 complete at 16:27:58, with 620 correct and 0 wrong
# 630 complete at 16:28:0, with 630 correct and 0 wrong
# 640 complete at 16:28:1, with 640 correct and 0 wrong
# 650 complete at 16:28:3, with 650 correct and 0 wrong
# 660 complete at 16:28:5, with 660 correct and 0 wrong
# 670 complete at 16:28:7, with 670 correct and 0 wrong
# 680 complete at 16:28:8, with 680 correct and 0 wrong
# 690 complete at 16:28:10, with 690 correct and 0 wrong
# 700 complete at 16:28:12, with 700 correct and 0 wrong
# 710 complete at 16:28:13, with 710 correct and 0 wrong
# 720 complete at 16:28:15, with 720 correct and 0 wrong
# 730 complete at 16:28:17, with 730 correct and 0 wrong
# 740 complete at 16:28:19, with 740 correct and 0 wrong
# 750 complete at 16:28:20, with 750 correct and 0 wrong
# 760 complete at 16:28:22, with 760 correct and 0 wrong
# 770 complete at 16:28:24, with 770 correct and 0 wrong
# 780 complete at 16:28:25, with 780 correct and 0 wrong
# 790 complete at 16:28:27, with 790 correct and 0 wrong
# 800 complete at 16:28:29, with 800 correct and 0 wrong
# 810 complete at 16:28:30, with 810 correct and 0 wrong
# 820 complete at 16:28:32, with 820 correct and 0 wrong
# 830 complete at 16:28:33, with 830 correct and 0 wrong
# 840 complete at 16:28:35, with 840 correct and 0 wrong
# 850 complete at 16:28:37, with 850 correct and 0 wrong
# 860 complete at 16:28:39, with 860 correct and 0 wrong
# 870 complete at 16:28:40, with 870 correct and 0 wrong
# 880 complete at 16:28:42, with 880 correct and 0 wrong
# 890 complete at 16:28:44, with 890 correct and 0 wrong
# 900 complete at 16:28:45, with 900 correct and 0 wrong
# 910 complete at 16:28:47, with 910 correct and 0 wrong
# 920 complete at 16:28:49, with 920 correct and 0 wrong
# 930 complete at 16:28:50, with 930 correct and 0 wrong
# 940 complete at 16:28:52, with 940 correct and 0 wrong
# 950 complete at 16:28:54, with 950 correct and 0 wrong
# 960 complete at 16:28:55, with 960 correct and 0 wrong
# 970 complete at 16:28:57, with 970 correct and 0 wrong
# 980 complete at 16:28:59, with 980 correct and 0 wrong
# 990 complete at 16:29:1, with 990 correct and 0 wrong
# 999 correct, 0 wrong, in 1000 tests, which took 168.83027052879333
